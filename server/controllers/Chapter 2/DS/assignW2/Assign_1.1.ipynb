# %%
a = 25
print ("a =", a, type(a))

b = 35.5
print ("b =", b, type(b))

c = a + b
print ("c =", a, "+", b, "=", c, type(c))
# Out:
# a = 25 <class 'int'>
# b = 35.5 <class 'float'>
# c = 25 + 35.5 = 60.5 <class 'float'>
