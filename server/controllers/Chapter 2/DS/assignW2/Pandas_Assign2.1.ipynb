# %%
import pandas as pd
data = {
    'DateOfBirt':['22/11/2568', '23/11/2568', '24/11/2568'],
    'name':['Ann', 'Boy', 'Bee'],
    'age':[20, 45, 33],
}

# %%
data
# Out:
# {'DateOfBirt': ['22/11/2568', '23/11/2568', '24/11/2568'],
#  'name': ['Ann', 'Boy', 'Bee'],
#  'age': [20, 45, 33]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    DateOfBirt name  age
# 0  22/11/2568  Ann   20
# 1  23/11/2568  Boy   45
# 2  24/11/2568  Bee   33

# %%
print (df.shape)
# Out:
# (3, 3)
