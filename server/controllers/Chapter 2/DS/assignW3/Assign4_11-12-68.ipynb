# %%
#Assignment4
import pandas as pd

# %%
df = pd.read_csv('data/OnlineRetail2.csv', encoding='unicode_escape')

# %%
pd.pivot_table(df, values='total', index=['Country', 'CustomerID'], aggfunc='sum')
# Out:
#                              total
# Country        CustomerID
# Australia      12386.0       13665
#                12388.0       94551
#                12393.0       53811
#                12415.0     4278713
#                12422.0       13132
# ...                            ...
# United Kingdom 18287.0       62465
# Unspecified    12363.0       18772
#                12743.0       18585
#                14265.0       18027
#                16320.0       35310
#
# [4380 rows x 1 columns]
