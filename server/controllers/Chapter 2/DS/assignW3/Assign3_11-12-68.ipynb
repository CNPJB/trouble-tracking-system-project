# %%
#Assignment3
fname = input("Enter your first name:")
lname = input("Enter your last name:")

print("Your name is: " + fname + lname)
# Out:
# Enter your first name: jane
# Enter your last name: doe
# Your name is: janedoe
