# %%
#Assignment5
import pandas as pd

# %%
df = pd.read_csv('data/OnlineRetail2.csv', encoding='unicode_escape')

# %%
df_pivot1 = pd.pivot_table(df, values=['total', 'Quantity'], index='StockCode', aggfunc={'Quantity':"sum",
                                                                                         'total':'mean'})
df_pivot2.rename(column={"Quantity
# Out:
#                              total
# StockCode    Quantity
# 10002        1           42.809524
#              2           92.636364
#              3           87.000000
#              4          116.000000
#              5          213.500000
# ...                            ...
# gift_0001_30 1          852.571429
#              30           0.000000
# gift_0001_40 1         1141.000000
# gift_0001_50 1         1424.500000
# m            1           87.000000
#
# [42148 rows x 1 columns]
