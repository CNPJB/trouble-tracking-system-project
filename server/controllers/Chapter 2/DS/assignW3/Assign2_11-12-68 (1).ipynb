# %%
#Assignment2

name = "Chitnupong"
id_std = "551"
gpa = 3.75
print("Hi, " "Mr. %s, " "Id: %s" %(name, id_std))
# Out:
# Hi, Mr. Chitnupong, Id: 551

# %%
print("Hi, " "Mr. %s, " "GPA: %.2f" %(name, gpa))
# Out:
# Hi, Mr. Chitnupong, GPA: 3.75

# %%
print("Hi, " "Id: %s, " "GPA: %.2f" %(name, id_std, gpa))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print("Hi, " "Id: %s, " "GPA: %.2f" %(name, id_std, gpa))
#
# TypeError: must be real number, not str
