# %%
#Assignment1
a = "Apple"

print(a[0])
print(a[-1])
print(a[-5])
print(a[4])
print(a[0:5])
print(a[0:5])
print(a[0:5])
print(a[3:5])
# Out:
# A
# e
# A
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 7
#       5 print(a[-1])
#       6 print(a[-5])
# ----> 7 print(a[5])
#       8 print(a[0:5])
#       9 print(a[0:5])
#
# IndexError: string index out of range
