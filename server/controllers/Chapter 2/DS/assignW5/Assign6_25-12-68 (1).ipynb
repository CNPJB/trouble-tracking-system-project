# %%
#Assignment6

data = (['A', 30000, 35],
        ['B', 40000, 40],
        ['C', 18000, 28],
        ['D', 80000, 50],
        ['E', 15000, 22])
sorted_data = sorted(data, key=lambda x: x[2])
for i in sorted_data:
    print(reversed(i))
