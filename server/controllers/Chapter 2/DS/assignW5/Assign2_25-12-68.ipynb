# %%
#Assignment2

file = open('line.txt','w')
file.write("Line 1\n")
file.write("Line 2\n")
file.write("Line 3\n")
file.close()

# %%
for line in reversed(list(open('line.txt'))) :
    print(line.rstrip())
# Out:
# Line 3
# Line 2
# Line 1
