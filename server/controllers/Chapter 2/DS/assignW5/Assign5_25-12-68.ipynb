# %%
#Assignment5
matrix = [[1, 2, 3], [4, 5], [6, 7, 8 ,9]]

result = []
for i in matrix[0] :
    result.append(i)
for j in matrix[1] :
    result.append(j)
for k in matrix[2] :
    result.append(k)

print(result)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
result2 = []
for i in matrix:
    for y in i:
        result2.append(y)
print(result2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
